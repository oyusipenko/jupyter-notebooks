# %%
print("Hello Alex"')
# Out:
#   File "<ipython-input-1-90e030765080>", line 1
#     print("Hello Alex"')
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
print("Hello Alex")
# Out:
# Hello Alex

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("hubble_data.csv")
data.head()
# Out:
#    distance  recession_velocity
# 0     0.032                 170
# 1     0.034                 290
# 2     0.214                -130
# 3     0.263                 -70
# 4     0.275                -185

# %%
headers = ["dist2","rec_vel2"]

data_no_headers = pd.read_csv("hubble_data_no_headers.csv", names=headers)

data_no_headers.head()
# Out:
#    dist2  rec_vel2
# 0  0.032       170
# 1  0.034       290
# 2  0.214      -130
# 3  0.263       -70
# 4  0.275      -185

# %%
data.set_index("distance", inplace=True)
data.head()
# Out:
#           recession_velocity
# distance
# 0.032                    170
# 0.034                    290
# 0.214                   -130
# 0.263                    -70
# 0.275                   -185

# %%
data.plot()
plt.show()
